# %% [markdown]
# # import modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import accuracy_score, precision_score, recall_score

# %% [markdown]
# # helper functions (if necessary)

# %%
#python code...

# %% [markdown]
# # read in training data

# %%
trainData = pd.read_csv("train.csv", delimiter=',')

# %% [markdown]
# # analyze and visualize training data

# %%
atrA = trainData['A']
atrB = trainData['B']
atrC = trainData['C']
atrD = trainData['D']
atrE = trainData['E']
atrF = trainData['F']
atrG = trainData['G']

y = trainData['Location']
X = trainData.drop(['Location'], axis = 1)

fig =seaborn.scatterplot(x = atrA, y = atrB, hue=y, palette=("deep"))
fig.set(title = "A vs B color locations", xlabel="A signal", ylabel="B signal")
plt.show()

fig =seaborn.scatterplot(x =atrA, y=atrC, hue=y, palette=("deep"))
fig.set(title = "A vs C color locations", xlabel="A signal", ylabel="C signal")
plt.show()

fig =seaborn.scatterplot(x=atrA, y=atrD, hue=y, palette=("deep"))
fig.set(title = "A vs D color locations", xlabel="A signal", ylabel="D signal")
plt.show()

fig =seaborn.scatterplot(x=atrA, y=atrE, hue=y, palette=("deep"))
fig.set(title = "A vs E color locations", xlabel="A signal", ylabel="E signal")
plt.show()

fig =seaborn.scatterplot(x=atrA, y=atrF, hue=y, palette=("deep"))
fig.set(title = "A vs F color locations", xlabel="A signal", ylabel="F signal")
plt.show()

fig =seaborn.scatterplot(x=atrA, y=atrG, hue=y, palette=("deep"))
fig.set(title = "A vs G color locations", xlabel="A signal", ylabel="G signal")
plt.show()

fig =seaborn.scatterplot(x=atrB, y=atrC, hue=y, palette=("deep"))
fig.set(title = "B vs C color locations", xlabel="B signal", ylabel="C signal")
plt.show()

fig =seaborn.scatterplot(x=atrB, y=atrD, hue=y, palette=("deep"))
fig.set(title = "B vs D color locations", xlabel="B signal", ylabel="D signal")
plt.show()

fig =seaborn.scatterplot(x=atrB, y=atrE, hue=y, palette=("deep"))
fig.set(title = "B vs E color locations", xlabel="B signal", ylabel="E signal")
plt.show()

fig =seaborn.scatterplot(x=atrB, y=atrF, hue=y, palette=("deep"))
fig.set(title = "B vs F color locations", xlabel="B signal", ylabel="F signal")
plt.show()

fig =seaborn.scatterplot(x=atrB, y=atrG, hue=y, palette=("deep"))
fig.set(title = "B vs G color locations", xlabel="B signal", ylabel="G signal")
plt.show()

fig =seaborn.scatterplot(x=atrC, y=atrD, hue=y, palette=("deep"))
fig.set(title = "C vs D color locations", xlabel="C signal", ylabel="D signal")
plt.show()

fig =seaborn.scatterplot(x=atrC, y=atrE, hue=y, palette=("deep"))
fig.set(title = "C vs E color locations", xlabel="C signal", ylabel="E signal")
plt.show()

fig =seaborn.scatterplot(x=atrC, y=atrF, hue=y, palette=("deep"))
fig.set(title = "C vs F color locations", xlabel="C signal", ylabel="F signal")
plt.show()

fig =seaborn.scatterplot(x=atrC, y=atrG, hue=y, palette=("deep"))
fig.set(title = "C vs G color locations", xlabel="C signal", ylabel="G signal")
plt.show()

fig =seaborn.scatterplot(x=atrD, y=atrE, hue=y, palette=("deep"))
fig.set(title = "D vs E color locations", xlabel="D signal", ylabel="E signal")
plt.show()

fig =seaborn.scatterplot(x=atrD, y=atrF, hue=y, palette=("deep"))
fig.set(title = "D vs F color locations", xlabel="D signal", ylabel="F signal")
plt.show()

fig =seaborn.scatterplot(x=atrD, y=atrG, hue=y, palette=("deep"))
fig.set(title = "D vs G color locations", xlabel="D signal" , ylabel="G signal")
plt.show()

fig =seaborn.scatterplot(x=atrE, y=atrF, hue=y, palette=("deep"))
fig.set(title = "E vs F color locations", xlabel="E signal", ylabel="F signal")
plt.show()

fig =seaborn.scatterplot(x=atrE, y=atrG, hue=y, palette=("deep"))
fig.set(title = "E vs G color locations", xlabel="E signal", ylabel="G signal")
plt.show()

fig =seaborn.scatterplot(x=atrF, y=atrG, hue=y, palette=("deep"))
fig.set(title = "F vs G color locations", xlabel="F signal" , ylabel="G signal")
plt.show()

fig = seaborn.boxplot(x = y, y = atrA)
fig.set(title = "A boxplots of locations" , ylabel="A signal")
plt.show()

fig = seaborn.boxplot(x = y, y = atrB)
fig.set(title = "B boxplots of locations", ylabel="B signal")
plt.show()

fig = seaborn.boxplot(x = y, y = atrC)
fig.set(title = "C boxplots of locations", ylabel="C signal")
plt.show()

fig = seaborn.boxplot(x = y, y = atrD)
fig.set(title = "D boxplots of locations", ylabel="D signal")
plt.show()

fig = seaborn.boxplot(x = y, y = atrE)
fig.set(title = "E boxplots of locations", ylabel="E signal")
plt.show()

fig = seaborn.boxplot(x = y, y = atrF)
fig.set(title = "F boxplots of locations" , ylabel="F signal")
plt.show()

fig = seaborn.boxplot(x = y, y = atrG)
fig.set(title = "G boxplots of locations", ylabel="G signal")
plt.show()

# %% [markdown]
# # experiment with classification

# %%
model = SVC()
model.fit(X, y)

y_pred = cross_val_predict(model, X, y, cv=5)
a = accuracy_score(y, y_pred)
p = precision_score(y, y_pred, average='macro')
r = recall_score(y, y_pred, average='macro')

print("all attributes-generic")
print("accuracy: "+ str(a))
print("percision: "+ str(p))
print("recall: "+ str(r))
print("\n")

model2 = SVC(kernel='poly')
model2.fit(X, y)

y_pred2 = cross_val_predict(model2, X, y, cv=5)
a2 = accuracy_score(y, y_pred2)
p2 = precision_score(y, y_pred2, average='macro')
r2 = recall_score(y, y_pred2, average='macro')

print("all attributes- poly kernel")
print("accuracy: "+ str(a2))
print("percision: "+ str(p2))
print("recall: "+ str(r2))
print("\n")

model3 = SVC(kernel='linear')
model3.fit(X, y)

y_pred3 = cross_val_predict(model3, X, y, cv=5)
a3 = accuracy_score(y, y_pred3)
p3 = precision_score(y, y_pred3, average='macro')
r3 = recall_score(y, y_pred3, average='macro')

print("all attributes- linear kernel")
print("accuracy: "+ str(a3))
print("percision: "+ str(p3))
print("recall: "+ str(r3))
print("\n")

X2 = X[['A','E','D']]
model4 = SVC()
model4.fit(X2, y)

y_pred4 = cross_val_predict(model4, X2, y, cv=5)
a4 = accuracy_score(y, y_pred4)
p4 = precision_score(y, y_pred4, average='macro')
r4 = recall_score(y, y_pred4, average='macro')

print("A E D-generic")
print("accuracy: "+ str(a4))
print("percision: "+ str(p4))
print("recall: "+ str(r4))
print("\n")

model2 = SVC(kernel='poly', degree = 4)
model2.fit(X, y)

y_pred2 = cross_val_predict(model2, X, y, cv=5)
a2 = accuracy_score(y, y_pred2)
p2 = precision_score(y, y_pred2, average='macro')
r2 = recall_score(y, y_pred2, average='macro')

print("all attributes- poly kernel degree 4")
print("accuracy: "+ str(a2))
print("percision: "+ str(p2))
print("recall: "+ str(r2))
print("\n")
# Out:
# all attributes-generic
# accuracy: 0.981875
# percision: 0.9821108283215966
# recall: 0.9820295609421128
#
#
# all attributes- poly kernel
# accuracy: 0.97875
# percision: 0.9788417306911275
# recall: 0.9788560904789017
#
#
# all attributes- linear kernel
# accuracy: 0.9775
# percision: 0.9775584560246724
# recall: 0.9776029576468215
#
#
# A E D-generic
# accuracy: 0.97875
# percision: 0.979040591911712
# recall: 0.9789459920690702
#
#
# all attributes- poly kernel degree 4
# accuracy: 0.975625
# percision: 0.9758126562224245
# recall: 0.9757506399045881

# %% [markdown]
# # Question: Which features and classification model parameters did you select?  Why?

# %% [markdown]
# For this data, all the features together made the best model that I could find. The parameteres I used in this model were the generic ones which include a c of 1, kernel of rbf, gamma of scale, class weight of none. I chose this combination of features and parameters because it preformed the best in accuracy, perceion and recall when I was testing out different combinations. None of the combinations I tried did horribly on this data set so I felt pretty good about picking this one because it appears to work the most accuratly while also keeping high amounts of recall and percision.

# %% [markdown]
# # train "fresh" model on training data

# %%
finalModel = SVC()
finalModel.fit(X, y)
# Out:
# SVC()

# %% [markdown]
# # read in test data

# %%
testData = pd.read_csv("test.csv", delimiter=',')

# %% [markdown]
# # run classification model on test data to make predictions

# %%
testloc = finalModel.predict(testData)
testData['Location']= testloc

# %% [markdown]
# # write test data with predictions to \<YourLastName>.csv

# %%
testData.to_csv('Cumro.csv', index=False, sep=',')
